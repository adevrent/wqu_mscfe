# %%
import pandas as pd
import requests

# Function to fetch loan data (replace with your data source)
def fetch_loan_data():
    # Example loan data as a DataFrame
    loan_data = pd.DataFrame({
        'Payment_Number': range(1, 37),  # Payment number
        'Payment_Date': pd.date_range(start='2023-01-01', periods=36, freq='M'),  # Payment date
        'Payment_Amount': [500.00] * 36,  # Monthly payment amount
        'Principal_Paid': [400.00] * 36,  # Amount paid toward principal
        'Interest_Paid': [100.00] * 36,  # Amount paid as interest
        'Loan_Balance': [10000.00] * 36  # Remaining loan balance
    })

    return loan_data

# Fetch loan data
loan_data = fetch_loan_data()

# Calculate the total number of payments
total_payments = len(loan_data)

# Print the amortization schedule
print(loan_data)

# Saving the amortization schedule to a CSV file
# loan_data.to_csv('amortization_schedule.csv', index=False)

# print("Amortization schedule has been saved to 'amortization_schedule.csv'")
# Out:
#     Payment_Number Payment_Date  Payment_Amount  Principal_Paid  \
# 0                1   2023-01-31           500.0           400.0
# 1                2   2023-02-28           500.0           400.0
# 2                3   2023-03-31           500.0           400.0
# 3                4   2023-04-30           500.0           400.0
# 4                5   2023-05-31           500.0           400.0
# 5                6   2023-06-30           500.0           400.0
# 6                7   2023-07-31           500.0           400.0
# 7                8   2023-08-31           500.0           400.0
# 8                9   2023-09-30           500.0           400.0
# 9               10   2023-10-31           500.0           400.0
# 10              11   2023-11-30           500.0           400.0
# 11              12   2023-12-31           500.0           400.0
# 12              13   2024-01-31           500.0           400.0
# 13              14   2024-02-29           500.0           400.0
# ...

# %% [markdown]
# In this example, the fetch_loan_data function retrieves loan data, including the payment number, payment date, payment amount, principal paid, interest paid, and the remaining loan balance. The loan data is represented as a pandas DataFrame.
#
# With the loan data in a DataFrame, we are calculating and displaying the entire amortization schedule based on the retrieved data. The provided code is a trimmed snippet, which can be expanded to include more data and additional loan details if needed.
